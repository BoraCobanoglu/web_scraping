# %%
from bs4 import BeautifulSoup 
import requests
import csv

# %%
from splinter import Browser
import webbrowser
executable_path = {"executable_path" : "chromedriver"}
browser = Browser("chrome", **executable_path, headless=True)
url = 'https://mars.nasa.gov/news/?page=0&per_page=40&order=publish_date+desc%2Ccreated_at+desc&search=&category=19%2C165%2C184%2C204&blank_scope=Latest'
browser.visit(url)
html = browser.html
soup = BeautifulSoup(html, 'html.parser')

# %%
article = soup.find('article')
print(article.prettify())
# Out:
# <article>
#  <header id="page_header">
#  </header>
# ...

# %%
paragraph = soup.find('div', class_ = "article_teaser_body").text
paragraph
# Out:
# "The Mars rover is moving on and has taken its last selfie on the ridge it's explored for more than a year."

# %%
title = soup.find('div', class_= "content_title").a.text
title
# Out:
# "Curiosity Says Farewell to Mars' Vera Rubin Ridge"

# %%
#_____________________________________________________FEATURED IMAGE____________________________________________________________

# %%
executable_path = {"executable_path" : "chromedriver"}
browser = Browser("chrome", **executable_path, headless=True)
url = "https://www.jpl.nasa.gov/spaceimages/details.php?id=PIA19048"
browser.visit(url)
html = browser.html
soup_img = BeautifulSoup(html, 'html.parser')

# %%
featured_image_url = soup_img.find('figure', class_="lede").a['href']
featured_image_url = "https://www.jpl.nasa.gov" + featured_image_url 
featured_image_url
# Out:
# 'https://www.jpl.nasa.gov/spaceimages/images/largesize/PIA19048_hires.jpg'

# %%
#_____________________________________________________TWITTER____________________________________________________________

# %%
executable_path = {"executable_path" : "chromedriver"}
browser = Browser("chrome", **executable_path, headless=True)
url = "https://twitter.com/marswxreport?lang=en"
browser.visit(url)
html = browser.html
soup_tweet = BeautifulSoup(html, 'html.parser')

# %%
weather = soup_tweet.find('p', class_ ="TweetTextSize TweetTextSize--normal js-tweet-text tweet-text").text
weather
#couldn't get the last tweet, I got the "pinned" tweet at the top, not the recent one.
# Out:
# 'High temps today across Canada and the upper midwest of the US didn’t reach Mars last reported high.pic.twitter.com/Zg0REwm8PI'

# %%
tweet = soup_tweet.find('div', class_="content")
tweet
